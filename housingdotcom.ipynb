# %%
import requests
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
s= Service("C:/Users/Menzk/Desktop/chromedriver_win32/chromedriver.exe")
driver=webdriver.Chrome(service=s)
#driver.get("https://housing.com/in/buy/searches/AB0CcD4M1P2to5k2425bdh9rxl_4ifenowjo8ksk4x5_21d0551ymfnxq3uc_2ns5n2rsa843nt5w_6v3kmtpj0f2oyp0tS0")
#driver.get("https://housing.com/in/buy/searches/AB0CcD4M1P3nlxhdfttdcshmss_2oo7qtrcv7or5boa_35q374v8w9496dkv_3zbn1e2nj8uk2ad8_1ggmxqdi0nye5vf0S0")
#driver.get("https://housing.com/in/buy/searches/AB0CcD4M1P1hv8kabu33j980rv_1tokohp70esscd5a_6ne1si6hotnhbq8S0")
#driver.get("https://housing.com/in/buy/searches/AB0CcD4M1Pmqo4qrsas4zu0vs_40sxuhgw6f0qbvy2S0")
#driver.get("https://housing.com/in/buy/searches/AB0CcD4M1P455awo9nnneeunbp_jecnctiyiinz5rs_3h1bv739bslvzwru_5ceo5dt6n9yigyxm_1q2jcrpwvv402wr5S0")
#driver.get("https://housing.com/in/buy/searches/AB0CcD4M1P1dkkevujirxf9yby_1q2jcrpwvv402wr5_4l9qv62v8ro55uco_5438x6ak00y2cxz5_6npf13jftu7qgnkqS0")
#driver.get("https://housing.com/in/buy/searches/AB0CcD4M1P2pkpxy5t1s0ct71d_6nbp8yriautwtv8g_jecnctiyiinz5rs_6w68ew6j3mdrkz8mS0")
#driver.get("https://housing.com/in/buy/searches/AB0CcD4M1P5tqm6z4herzc5jyeS0")-Er
#driver.get("https://housing.com/in/buy/searches/AB0CcD4M1Pl1tevc60dsca2ys_5ki7d1ubthx23827_2p6e16trctzp4ia4_wqf94e82uwflmytS0")
driver.get("https://housing.com/in/buy/searches/AB0CcD4M1P14oyohv2em6zmn2m_2uk96ghzubh4j2c0_4w4fo89h8t83ghuv_4ireddbfld6h03voS0")
last_height = driver.execute_script("return document.body.scrollHeight")
price_list=[]
project_list=[]
Avgprice=[]
builder=[]
bhk=[]
locations=[]
listedby=[]
df = pd.DataFrame(columns=['Price',"ProjectName","Avg Price"])
df2 = pd.DataFrame(columns=['b'])

while True:
    driver.execute_script("scrollTo(0, document.body.scrollHeight);")
 
    data = BeautifulSoup(driver.page_source,'html5lib')
    arti=data.find_all("article",class_="css-1nr7r9e")
    for i in arti:
        price_list=i.find('div',class_="css-18rodr0").text   
        #print(price_list)
        project_list=i.find('div',class_="css-2rx1iy").text
        Possessionstatus=i.select('div.css-4z3njv')[0].text
        
        Avgprice=i.select('div.css-4z3njv')[1].text
        
        locations=i.find('div',class_='_6w1e54 _9scj1k _fycs5v _ks15vq _fr1tw0 _h3ftgi')
        if locations is None:
            locations=""
            continue
        else:
             locations=locations.text
            #print(locations)
        builder=i.find('div',class_='css-1j62xqm')
       
        if builder is None:
            builder=""
            continue
        else:
             builder=builder.text
        bhk=i.find('h3',class_='css-197fqpq').text.strip()
        #print(bhk)   
        listedby=i.find('div',class_='css-1rvtriw').text
        #print(listedby)
        df=df.append({"Price":price_list,"ProjectName":project_list,"Avg Price":Avgprice,"Builder":builder,"bhk":bhk,"Location":locations,"Possession Status":Possessionstatus,"ListedBy":listedby},ignore_index=True)
        #df2=df2.append({"b":builder},ignore_index=True)
    time.sleep(15)
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
df
#df['bhk'] = df['bhk'].str.split(', ')        
#df.to_csv("hosing_pallavaram.csv")
df.to_csv("hosing_cgl2.csv")
